# %%
import lsdb
from tape import Ensemble, ColumnMapper
import matplotlib.pyplot as plt

# %% [markdown]
# # Demo: Cross-matching ZTF and Gaia with LSDB & Timeseries Exploration with TAPE

# %% [markdown]
# In this demo, we'll show a brief example LSDB+TAPE workflow using ZTF+Gaia data. The dataset we'll use is a small half-degree subset of ZTF and Gaia, hosted here: https://epyc.astro.washington.edu/~lincc-frameworks/half_degree_surveys/
#
# The goal of this notebook is to provide example code for working with Gaia+ZTF data, and using this as the foundation for your own analysis with TAPE, LSDB and ZTF+Gaia is highly encouraged.
#
# Requires LSDB >=0.1.2, hipscat>0.2.4

# %% [markdown]
# ## Installation and Dependencies
#
# TAPE: https://tape.readthedocs.io/en/latest/gettingstarted/installation.html
# ```
# pip install lf-tape
# ```
# LSDB:
# ```
# pip install lsdb
# ```
#
# This notebook also requires hipscat>0.2.4, at the current moment 0.2.4 is the latest release, so hipscat will need to be installed from source:
# ```
# conda activate [YOUR CONDA ENVIRONMENT OF CHOICE]
# git clone https://github.com/astronomy-commons/hipscat.git
# cd hipscat
# pip install .
# ```

# %% [markdown]
# ## Reading into LSDB

# %%
#Setup Paths

# Gaia
gaia_object_path = "https://epyc.astro.washington.edu/~lincc-frameworks/half_degree_surveys/gaia_symbolic/"

# ZTF
ztf_object_path = "https://epyc.astro.washington.edu/~lincc-frameworks/half_degree_surveys/ztf/ztf_object/"
ztf_source_path = "https://epyc.astro.washington.edu/~lincc-frameworks/half_degree_surveys/ztf/ztf_source/"
# optionally can use Zubercal for ztf sources (observations) instead
#ztf_source_path = "https://epyc.astro.washington.edu/~lincc-frameworks/half_degree_surveys/ztf/zubercal_source/"

# %%
# Load into LSDB Catalog objects
gaia_object = lsdb.read_hipscat(gaia_object_path) # Gaia Object
ztf_object = lsdb.read_hipscat(ztf_object_path) # ZTF Object
ztf_source = lsdb.read_hipscat(ztf_source_path) # ZTF Source

# %%
print(len(gaia_object._ddf), len(ztf_object._ddf))
# Out:
# 2509 9817

# %%
# Cross-match Gaia and ZTF

xmatch_object = ztf_object.crossmatch(gaia_object)

xmatch_object._ddf.head(5)
# Out:
# /Users/dbranton/miniforge3/envs/ray310/lib/python3.10/site-packages/lsdb/dask/crossmatch_catalog_data.py:100: RuntimeWarning: Right catalog does not have a margin cache. Results may be inaccurate
#   warnings.warn("Right catalog does not have a margin cache. Results may be inaccurate", RuntimeWarning)
#                      ps1_objid_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216               119401799937858008  \
# 7800231386677248000               119401800526045557
# 7800231722905239552               119421800537485698
# 7800231851490017280               119411800119230905
# 7800231854853849088               119411800168234041
#
#                      ra_ztf_object_halfdegree  dec_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                179.993698                   9.506274  \
# 7800231386677248000                180.052521                   9.504200
# 7800231722905239552                180.053670                   9.521045
# 7800231851490017280                180.011831                   9.508711
# 7800231854853849088                180.016739                   9.511301
#
#                      ps1_gMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                                19.1936  \
# 7800231386677248000                                17.3981
# 7800231722905239552                                19.9639
# 7800231851490017280                                21.1581
# 7800231854853849088                                19.2582
#
#                      ps1_rMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              18.894199  \
# 7800231386677248000                              16.220200
# 7800231722905239552                              19.621799
# 7800231851490017280                              20.547899
# 7800231854853849088                              18.205400
#
#                      ps1_iMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                                18.7934  \
# 7800231386677248000                                15.1036
# 7800231722905239552                                19.4827
# 7800231851490017280                                20.3141
# 7800231854853849088                                18.0648
#
#                      nobs_g_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           271  \
# 7800231386677248000                           289
# 7800231722905239552                           235
# 7800231851490017280                            96
# 7800231854853849088                           266
#
#                      nobs_r_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           346  \
# 7800231386677248000                           363
# 7800231722905239552                           309
# 7800231851490017280                           188
# 7800231854853849088                           360
#
#                      nobs_i_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           124  \
# 7800231386677248000                           128
# 7800231722905239552                           116
# 7800231851490017280                            87
# 7800231854853849088                           125
#
#                      mean_mag_g_ztf_object_halfdegree  ...
# _hipscat_index                                         ...
# 7800231224164745216                         19.213742  ...  \
# 7800231386677248000                         17.479837  ...
# 7800231722905239552                         19.966760  ...
# 7800231851490017280                         21.037499  ...
# 7800231854853849088                         19.123036  ...
#
#                      ag_gspphot_lower_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0006  \
# 7800231386677248000                            0.4366
# 7800231722905239552                               NaN
# 7800231851490017280                               NaN
# 7800231854853849088                               NaN
#
#                      ag_gspphot_upper_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0070  \
# 7800231386677248000                            0.4575
# 7800231722905239552                               NaN
# 7800231851490017280                               NaN
# 7800231854853849088                               NaN
#
#                      ebpminrp_gspphot_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0016  \
# 7800231386677248000                            0.2732
# 7800231722905239552                               NaN
# 7800231851490017280                               NaN
# 7800231854853849088                               NaN
#
#                      ebpminrp_gspphot_lower_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                                  0.0003  \
# 7800231386677248000                                  0.2678
# 7800231722905239552                                     NaN
# 7800231851490017280                                     NaN
# 7800231854853849088                                     NaN
#
#                      ebpminrp_gspphot_upper_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                                  0.0039  \
# 7800231386677248000                                  0.2804
# 7800231722905239552                                     NaN
# 7800231851490017280                                     NaN
# 7800231854853849088                                     NaN
#
#                      libname_gspphot_gaia_halfdegree Norder_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            MARCS                      2  \
# 7800231386677248000                            MARCS                      2
# 7800231722905239552                             None                      2
# 7800231851490017280                             None                      2
# 7800231854853849088                             None                      2
#
#                      Npix_gaia_halfdegree  Dir_gaia_halfdegree     _DIST
# _hipscat_index
# 7800231224164745216                   108                  108  0.000031
# 7800231386677248000                   108                  108  0.000018
# 7800231722905239552                   108                  108  0.000036
# 7800231851490017280                   108                  108  0.000037
# 7800231854853849088                   108                  108  0.000033
#
# [5 rows x 171 columns]

# %%
# Filter the dataset using a SQL-like query
xmatch_object = xmatch_object.query(
    "nobs_g_ztf_object_halfdegree > 150 and nobs_r_ztf_object_halfdegree > 150"  # the column names are a bit verbose...
)

xmatch_object._ddf.head(5)
# Out:
#                      ps1_objid_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216               119401799937858008  \
# 7800231386677248000               119401800526045557
# 7800231722905239552               119421800537485698
# 7800231854853849088               119411800168234041
# 7800232001469939712               119421800126897863
#
#                      ra_ztf_object_halfdegree  dec_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                179.993698                   9.506274  \
# 7800231386677248000                180.052521                   9.504200
# 7800231722905239552                180.053670                   9.521045
# 7800231854853849088                180.016739                   9.511301
# 7800232001469939712                180.012578                   9.522857
#
#                      ps1_gMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              19.193600  \
# 7800231386677248000                              17.398100
# 7800231722905239552                              19.963900
# 7800231854853849088                              19.258200
# 7800232001469939712                              20.105801
#
#                      ps1_rMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              18.894199  \
# 7800231386677248000                              16.220200
# 7800231722905239552                              19.621799
# 7800231854853849088                              18.205400
# 7800232001469939712                              18.949301
#
#                      ps1_iMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              18.793400  \
# 7800231386677248000                              15.103600
# 7800231722905239552                              19.482700
# 7800231854853849088                              18.064800
# 7800232001469939712                              17.642099
#
#                      nobs_g_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           271  \
# 7800231386677248000                           289
# 7800231722905239552                           235
# 7800231854853849088                           266
# 7800232001469939712                           221
#
#                      nobs_r_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           346  \
# 7800231386677248000                           363
# 7800231722905239552                           309
# 7800231854853849088                           360
# 7800232001469939712                           355
#
#                      nobs_i_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           124  \
# 7800231386677248000                           128
# 7800231722905239552                           116
# 7800231854853849088                           125
# 7800232001469939712                           127
#
#                      mean_mag_g_ztf_object_halfdegree  ...
# _hipscat_index                                         ...
# 7800231224164745216                         19.213742  ...  \
# 7800231386677248000                         17.479837  ...
# 7800231722905239552                         19.966760  ...
# 7800231854853849088                         19.123036  ...
# 7800232001469939712                         20.175254  ...
#
#                      ag_gspphot_lower_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0006  \
# 7800231386677248000                            0.4366
# 7800231722905239552                               NaN
# 7800231854853849088                               NaN
# 7800232001469939712                            0.1346
#
#                      ag_gspphot_upper_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0070  \
# 7800231386677248000                            0.4575
# 7800231722905239552                               NaN
# 7800231854853849088                               NaN
# 7800232001469939712                            0.1949
#
#                      ebpminrp_gspphot_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0016  \
# 7800231386677248000                            0.2732
# 7800231722905239552                               NaN
# 7800231854853849088                               NaN
# 7800232001469939712                            0.1110
#
#                      ebpminrp_gspphot_lower_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                                  0.0003  \
# 7800231386677248000                                  0.2678
# 7800231722905239552                                     NaN
# 7800231854853849088                                     NaN
# 7800232001469939712                                  0.0913
#
#                      ebpminrp_gspphot_upper_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                                  0.0039  \
# 7800231386677248000                                  0.2804
# 7800231722905239552                                     NaN
# 7800231854853849088                                     NaN
# 7800232001469939712                                  0.1311
#
#                      libname_gspphot_gaia_halfdegree Norder_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            MARCS                      2  \
# 7800231386677248000                            MARCS                      2
# 7800231722905239552                             None                      2
# 7800231854853849088                             None                      2
# 7800232001469939712                            MARCS                      2
#
#                      Npix_gaia_halfdegree  Dir_gaia_halfdegree     _DIST
# _hipscat_index
# 7800231224164745216                   108                  108  0.000031
# 7800231386677248000                   108                  108  0.000018
# 7800231722905239552                   108                  108  0.000036
# 7800231854853849088                   108                  108  0.000033
# 7800232001469939712                   108                  108  0.000040
#
# [5 rows x 171 columns]

# %% [markdown]
# ## Moving into TAPE for timeseries analysis

# %%
# We do this to get the source catalog indexed by the objects hipscat index
joined_source = xmatch_object.join(
    ztf_source, left_on="ps1_objid_ztf_object_halfdegree", right_on="ps1_objid", suffixes=("", "")
)

# Loading into TAPE
ens = Ensemble(client=False)

# You may also want to try using a distributed client, opening up access to helpful resources
# like the dask dashboard: https://docs.dask.org/en/latest/dashboard.html
#from dask.distributed import Client
#client = Client(n_workers=4)
#ens = Ensemble(client=client)

# The ColumnMapper maps dataset columns to a few timeseries quantities
colmap = ColumnMapper(
        id_col='_hipscat_index',
        time_col='mjd',
        flux_col='mag',
        err_col='magerr',
        band_col='band',
      )

ens.from_lsdb(joined_source, xmatch_object, column_mapper=colmap, sync_tables=True)

ens.object.head(5, npartitions=-1)
# Out:
#                      ps1_objid_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216               119401799937858008  \
# 7800231386677248000               119401800526045557
# 7800231722905239552               119421800537485698
# 7800231854853849088               119411800168234041
# 7800232001469939712               119421800126897863
#
#                      ra_ztf_object_halfdegree  dec_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                179.993698                   9.506274  \
# 7800231386677248000                180.052521                   9.504200
# 7800231722905239552                180.053670                   9.521045
# 7800231854853849088                180.016739                   9.511301
# 7800232001469939712                180.012578                   9.522857
#
#                      ps1_gMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              19.193600  \
# 7800231386677248000                              17.398100
# 7800231722905239552                              19.963900
# 7800231854853849088                              19.258200
# 7800232001469939712                              20.105801
#
#                      ps1_rMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              18.894199  \
# 7800231386677248000                              16.220200
# 7800231722905239552                              19.621799
# 7800231854853849088                              18.205400
# 7800232001469939712                              18.949301
#
#                      ps1_iMeanPSFMag_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                              18.793400  \
# 7800231386677248000                              15.103600
# 7800231722905239552                              19.482700
# 7800231854853849088                              18.064800
# 7800232001469939712                              17.642099
#
#                      nobs_g_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           271  \
# 7800231386677248000                           289
# 7800231722905239552                           235
# 7800231854853849088                           266
# 7800232001469939712                           221
#
#                      nobs_r_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           346  \
# 7800231386677248000                           363
# 7800231722905239552                           309
# 7800231854853849088                           360
# 7800232001469939712                           355
#
#                      nobs_i_ztf_object_halfdegree
# _hipscat_index
# 7800231224164745216                           124  \
# 7800231386677248000                           128
# 7800231722905239552                           116
# 7800231854853849088                           125
# 7800232001469939712                           127
#
#                      mean_mag_g_ztf_object_halfdegree  ...
# _hipscat_index                                         ...
# 7800231224164745216                         19.213742  ...  \
# 7800231386677248000                         17.479837  ...
# 7800231722905239552                         19.966760  ...
# 7800231854853849088                         19.123036  ...
# 7800232001469939712                         20.175254  ...
#
#                      ag_gspphot_lower_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0006  \
# 7800231386677248000                            0.4366
# 7800231722905239552                               NaN
# 7800231854853849088                               NaN
# 7800232001469939712                            0.1346
#
#                      ag_gspphot_upper_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0070  \
# 7800231386677248000                            0.4575
# 7800231722905239552                               NaN
# 7800231854853849088                               NaN
# 7800232001469939712                            0.1949
#
#                      ebpminrp_gspphot_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            0.0016  \
# 7800231386677248000                            0.2732
# 7800231722905239552                               NaN
# 7800231854853849088                               NaN
# 7800232001469939712                            0.1110
#
#                      ebpminrp_gspphot_lower_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                                  0.0003  \
# 7800231386677248000                                  0.2678
# 7800231722905239552                                     NaN
# 7800231854853849088                                     NaN
# 7800232001469939712                                  0.0913
#
#                      ebpminrp_gspphot_upper_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                                  0.0039  \
# 7800231386677248000                                  0.2804
# 7800231722905239552                                     NaN
# 7800231854853849088                                     NaN
# 7800232001469939712                                  0.1311
#
#                      libname_gspphot_gaia_halfdegree Norder_gaia_halfdegree
# _hipscat_index
# 7800231224164745216                            MARCS                      2  \
# 7800231386677248000                            MARCS                      2
# 7800231722905239552                             None                      2
# 7800231854853849088                             None                      2
# 7800232001469939712                            MARCS                      2
#
#                      Npix_gaia_halfdegree  Dir_gaia_halfdegree     _DIST
# _hipscat_index
# 7800231224164745216                   108                  108  0.000031
# 7800231386677248000                   108                  108  0.000018
# 7800231722905239552                   108                  108  0.000036
# 7800231854853849088                   108                  108  0.000033
# 7800232001469939712                   108                  108  0.000040
#
# [5 rows x 171 columns]
