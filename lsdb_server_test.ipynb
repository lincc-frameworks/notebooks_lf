# %%
import lsdb
# Out:
# INFO:numexpr.utils:Note: detected 128 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 128 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 16.
# INFO:numexpr.utils:NumExpr defaulting to 16 threads.

# %%
test= lsdb.open_catalog("https://server.data.lsdb.io/hats/gaia_dr3/")

# %%
test
# Out:
# Dask NestedFrame Structure:
# ...

# %%
test= lsdb.open_catalog("https://server.data.lsdb.io/hats/gaia_dr3/gaia/", 
    columns=["source_id", "ra", "dec", "phot_bp_mean_mag", 'pm'],
    filters=[('pm','>',5)]).compute()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 test= lsdb.open_catalog("https://server.data.lsdb.io/hats/gaia_dr3/gaia/",
#       2     columns=["source_id", "ra", "dec", "phot_bp_mean_mag", 'pm'],
# ----> 3     filters=[('pm','>',5)]).compute()
#
# File ~/.local/lib/python3.13/site-packages/lsdb/catalog/dataset/dataset.py:62, in Dataset.compute(self)
#      60 def compute(self) -> npd.NestedFrame:
#      61     """Compute dask distributed dataframe to pandas dataframe"""
# ---> 62     return self._ddf.compute()
#
# File ~/.local/lib/python3.13/site-packages/lsdb/nested/core.py:436, in NestedFrame.compute(self, **kwargs)
#     434 def compute(self, **kwargs):
#     435     """Compute this Dask collection, returning the underlying dataframe or series."""
# --> 436     return npd.NestedFrame(super().compute(**kwargs))
#
# ...

# %%
test
# Out:
# Dask NestedFrame Structure:
#                           source_id               ra              dec phot_bp_mean_mag              pm
# npartitions=2016
# 0                    int64[pyarrow]  double[pyarrow]  double[pyarrow]   float[pyarrow]  float[pyarrow]
# 18014398509481984               ...              ...              ...              ...             ...
# ...                             ...              ...              ...              ...             ...
# 3454260914193170432             ...              ...              ...              ...             ...
# 3458764513820540928             ...              ...              ...              ...             ...
# Dask Name: nestedframe, 3 expressions
# Expr=MapPartitions(NestedFrame)
