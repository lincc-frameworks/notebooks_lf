# %%
import lsdb

# %%
gaia = lsdb.open_catalog('https://data.lsdb.io/hats/gaia_dr3')
gaia
# Out:
# Dask NestedFrame Structure:
# ...

# %%
ztf = lsdb.open_catalog('https://data.lsdb.io/hats/ztf_dr14')
ztf
# Out:
# Dask NestedFrame Structure:
#                           ps1_objid               ra              dec  ps1_gMeanPSFMag  ps1_rMeanPSFMag  ps1_iMeanPSFMag          nobs_g          nobs_r          nobs_i       mean_mag_g       mean_mag_r       mean_mag_i
# npartitions=2352
# 0                    int64[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]  int32[pyarrow]  int32[pyarrow]  int32[pyarrow]  double[pyarrow]  double[pyarrow]  double[pyarrow]
# 4503599627370496                ...              ...              ...              ...              ...              ...             ...             ...             ...              ...              ...              ...
# ...                             ...              ...              ...              ...              ...              ...             ...             ...             ...              ...              ...              ...
# ...

# %%
ztf.crossmatch(gaia)
# Out:
# /Users/smcmu/code/lsdb/src/lsdb/catalog/catalog.py:274: FutureWarning: The default suffix behavior will change from applying suffixes to all columns to only applying suffixes to overlapping columns in a future release.To maintain the current behavior, explicitly set `suffix_method='all_columns'`. To change to the new behavior, set `suffix_method='overlapping_columns'`.
#   warnings.warn(
# Dask NestedFrame Structure:
# ...

# %%
cat = ztf.crossmatch(gaia, suffix_method="overlapping_columns")
cat
# Out:
# WARNING:root:Renaming overlapping columns:
# +--------+-------------------------+----------------------+
# | Column | Left (suffix=_ztf_dr14) | Right (suffix=_gaia) |
# +--------+-------------------------+----------------------+
# |  dec   |      dec_ztf_dr14       |       dec_gaia       |
# |   ra   |       ra_ztf_dr14       |       ra_gaia        |
# +--------+-------------------------+----------------------+
# Dask NestedFrame Structure:
# ...

# %%
cat.partitions[0].compute()
# Out:
#                            ps1_objid  ra_ztf_dr14  dec_ztf_dr14  \
# _healpix_29
# 3122680427        108000449961107213    44.996152      0.005626
# 29154369144       108020450049144323    45.004993       0.01991
# ...                              ...          ...           ...
# 4503538076566186  119470450008269577    45.000845      9.565911
# 4503563812968392  119490450066146265    45.006649      9.579828
#
#                   ps1_gMeanPSFMag  ps1_rMeanPSFMag  ps1_iMeanPSFMag  nobs_g  \
# _healpix_29
# 3122680427                18.1133          17.6278          17.4065     364
# 29154369144               14.8925          14.1057          13.7921     371
# ...                           ...              ...              ...     ...
# 4503538076566186        20.060801          19.0581          18.6035     201
# 4503563812968392        17.502199        16.786699          16.4648     260
#
#                   nobs_r  nobs_i  mean_mag_g  ...  azero_gspphot_lower  \
# ...
