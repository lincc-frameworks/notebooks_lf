# %% [markdown]
# # Extrema search comparison
#
# Author: Melissa
#
# Companion notebook to that other one. This just runs the vanilla full-table scan to find those 8 nearby stars using plain on dask/lsdb stuff.

# %%
import lsdb

# %%
gaia_d = lsdb.open_catalog("/epyc/data3/hats/catalogs/gaia_edr3_distances")

# %%
# %%time
gaia_d.query('r_med_photogeo < 3').compute()
# Out:
# CPU times: user 15min 59s, sys: 8min 34s, total: 24min 34s
# Wall time: 3min 47s
#                                source_id  r_med_geo  r_lo_geo  r_hi_geo  \
# _healpix_29
# 381407739701909405    762815470562110464   2.545952  2.545706  2.546205
# 1473525239409412345  2947050466531873024   2.670147  2.668469  2.671663
# 1932486467174911786  3864972938605115520   2.408358  2.407998  2.408747
# 2037570889377880190  4075141768785646848   2.975431  2.975131  2.975705
# 2236416425020061922  4472832130942575872   1.828106  1.827975  1.828225
# 2570346799484574619  5140693571158739840   2.718584  2.713234  2.724433
# 2570346800245147123  5140693571158946048    2.67459   2.67066  2.678184
# 2926749359394994434  5853498713190525696   1.301911  1.301814  1.302005
#
#                      r_med_photogeo  r_lo_photogeo  r_hi_photogeo   flag  \
# _healpix_29
# 381407739701909405         2.545851       2.545692       2.546106  10033
# ...
