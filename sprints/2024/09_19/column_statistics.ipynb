# %% [markdown]
# # Column statistics
#
# Author: Melissa
#
# Using parquet metadata's row group statistics, we can gather information about the global minimum and maximum values, as well as the total number of null values.
#
# Other statistics would be tricky to gather, and would require full scans of the data. With this approach, we need only read the `_metadata` file, and we get ALL of the row group statistics for ALL files at once.
#
# More caveats:
# * This is not checked in yet. the hipscat -> HATS transition is taking precendence right now
# * I think I'd also like to consider only a subset of partitions. In this way, you could explicitly only get the ones you want, or you could perform some cone search and get the statistics for partitions that overlap that cone. It would make the method more complicated, so I'd only like to do that if it's something that sounds appealing to scientist customers.
# * This notebook showcases the generic method that gathers the statistics for the `_metadata` file, but I'd like to have a convenience method on the catalog that does the path manipulation (and considers only the effective set of partitions, if the above is implemented)
# * Null count might not be a very useful statistics for folks. But it's free in the `_metadata` file statistics. Could add an option to suppress that column from the result I guess?

# %%
from hipscat.io.parquet_metadata import aggregate_column_statistics

small_sky_metadata = "/home/delucchi/git/stats/hipscat/tests/data/small_sky_order1/_metadata"

# %% [markdown]
# ## Simple small sky example
#
# With everyone's favorite unit test data set, we can look at some of the initial features.
#
# - excludes "hipscat columns" by default (`_hipscat_index`, `Norder`, `Dir`, and `Npix`)
# - allows specification of specific columns to include or exclude

# %%
aggregate_column_statistics(small_sky_metadata)
# Out:
#   column_names  min_value  max_value  null_count
# 0           id      700.0      830.0         0.0
# 1           ra      280.5      350.5         0.0
# 2          dec      -69.5      -25.5         0.0
# 3     ra_error        0.0        0.0         0.0
# 4    dec_error        0.0        0.0         0.0

# %%
aggregate_column_statistics(small_sky_metadata, exclude_hipscat_columns=False)
# Out:
#      column_names     min_value     max_value  null_count
# 0              id  7.000000e+02  8.300000e+02         0.0
# 1              ra  2.805000e+02  3.505000e+02         0.0
# 2             dec -6.950000e+01 -2.550000e+01         0.0
# 3        ra_error  0.000000e+00  0.000000e+00         0.0
# 4       dec_error  0.000000e+00  0.000000e+00         0.0
# 5          Norder  1.000000e+00  1.000000e+00         0.0
# 6             Dir  0.000000e+00  0.000000e+00         0.0
# 7            Npix  4.400000e+01  4.700000e+01         0.0
# 8  _hipscat_index  1.274969e+19  1.369672e+19         0.0

# %%
aggregate_column_statistics(small_sky_metadata, include_columns=["ra", "dec"])
# Out:
#   column_names  min_value  max_value  null_count
# 0           ra      280.5      350.5         0.0
# 1          dec      -69.5      -25.5         0.0

# %% [markdown]
# ## Where things are less pretty

# %%
# %%time

gaia_stats = aggregate_column_statistics('https://data.lsdb.io/unstable/gaia_dr3/gaia/_metadata')
# Out:
# CPU times: user 4.14 s, sys: 293 ms, total: 4.44 s
# Wall time: 13.9 s

# %%
gaia_stats
# Out:
#                column_names                     min_value  \
# 0               solution_id           1636148068921376768
# 1               designation  Gaia DR3 1000000057322000000
# 2                 source_id                    4295806720
# 3              random_index                             0
# 4                 ref_epoch                        2016.0
# ..                      ...                           ...
# 147        ag_gspphot_upper                        0.0001
# 148        ebpminrp_gspphot                          -0.0
# 149  ebpminrp_gspphot_lower                          -0.0
# 150  ebpminrp_gspphot_upper                        0.0001
# 151         libname_gspphot                             A
#
#                        max_value  null_count
# 0            1636148068921376768           0
# 1    Gaia DR3 999999988604363776           0
# 2            6917528997577384320           0
# 3                     1811709770           0
# 4                         2016.0           0
# ..                           ...         ...
# 147                       7.4111  1340950508
# 148                       4.2257  1340950508
# 149                       4.2245  1340950508
# 150                       4.2262  1340950508
# 151                      PHOENIX  1340950508
#
# [152 rows x 4 columns]

# %% [markdown]
# Pandas only shows the first few and last few rows, when there's a lot of data. You can get around this with a pandas option, and I think we should have a demo notebook that showcases this functionality that calls out the pandas options.

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
gaia_stats
# Out:
#                         column_names                     min_value  \
# 0                        solution_id           1636148068921376768
# 1                        designation  Gaia DR3 1000000057322000000
# 2                          source_id                    4295806720
# 3                       random_index                             0
# 4                          ref_epoch                        2016.0
# 5                                 ra         3.409623912662645e-07
# 6                           ra_error                  0.0035371692
# 7                                dec            -89.99287859590359
# 8                          dec_error                  0.0042951643
# 9                           parallax            -187.0293963742349
# 10                    parallax_error                  0.0071899574
# 11               parallax_over_error                    -161.38797
# 12                                pm                 0.00019370936
# 13                              pmra            -4406.469178827325
# 14                        pmra_error                  0.0039596637
# 15                             pmdec           -5817.8001940492695
# 16                       pmdec_error                  0.0052927267
# 17                       ra_dec_corr                   -0.99999934
# 18                  ra_parallax_corr                    -0.9839409
# 19                      ra_pmra_corr                    -0.9934673
# 20                     ra_pmdec_corr                     -0.995595
# 21                 dec_parallax_corr                   -0.99205256
# 22                     dec_pmra_corr                   -0.99342203
# 23                    dec_pmdec_corr                    -0.9971704
# 24                parallax_pmra_corr                    -0.9512427
# 25               parallax_pmdec_corr                   -0.95243996
# 26                   pmra_pmdec_corr                   -0.99655056
# 27              astrometric_n_obs_al                            12
# 28              astrometric_n_obs_ac                             0
# 29         astrometric_n_good_obs_al                            10
# 30          astrometric_n_bad_obs_al                             0
# 31                astrometric_gof_al                    -31.882742
# 32               astrometric_chi2_al                      2.730088
# 33          astrometric_excess_noise                          -0.0
# 34      astrometric_excess_noise_sig                          -0.0
# 35         astrometric_params_solved                             3
# 36          astrometric_primary_flag                         False
# 37         nu_eff_used_in_astrometry                  -0.116922274
# 38                      pseudocolour                    -3.2705555
# 39                pseudocolour_error                  0.0010687921
# 40              ra_pseudocolour_corr                    -0.9319211
# 41             dec_pseudocolour_corr                     -0.936728
# 42        parallax_pseudocolour_corr                    -0.9124055
# 43            pmra_pseudocolour_corr                   -0.92151284
# 44           pmdec_pseudocolour_corr                   -0.88240075
# 45      astrometric_matched_transits                             5
# 46           visibility_periods_used                             1
# 47           astrometric_sigma5d_max                   0.009942858
# 48                  matched_transits                             5
# 49              new_matched_transits                             0
# 50          matched_transits_removed                             0
# 51        ipd_gof_harmonic_amplitude                  7.657361e-07
# 52            ipd_gof_harmonic_phase                 1.6501097e-08
# 53               ipd_frac_multi_peak                             0
# 54                  ipd_frac_odd_win                             0
# 55                              ruwe                    0.19239865
# 56        scan_direction_strength_k1                 8.8557845e-06
# 57        scan_direction_strength_k2                  6.427706e-06
# 58        scan_direction_strength_k3                 3.2243884e-06
# 59        scan_direction_strength_k4                 1.9830339e-05
# 60            scan_direction_mean_k1                        -180.0
# 61            scan_direction_mean_k2                         -90.0
# 62            scan_direction_mean_k3                         -60.0
# 63            scan_direction_mean_k4                         -45.0
# 64                 duplicated_source                         False
# 65                      phot_g_n_obs                             0
# 66                  phot_g_mean_flux            12.370194398444749
# 67            phot_g_mean_flux_error                    0.27475065
# 68       phot_g_mean_flux_over_error                     1.0823672
# 69                   phot_g_mean_mag                      1.731607
# 70                     phot_bp_n_obs                             0
# 71                 phot_bp_mean_flux            1.0050400371436263
# 72           phot_bp_mean_flux_error                          -0.0
# 73      phot_bp_mean_flux_over_error                   0.053431902
# 74                  phot_bp_mean_mag                     2.3980012
# 75                     phot_rp_n_obs                             0
# 76                 phot_rp_mean_flux            1.0489614290056928
# 77           phot_rp_mean_flux_error                          -0.0
# 78      phot_rp_mean_flux_over_error                   0.054578356
# 79                  phot_rp_mean_mag                     1.7436333
# 80          phot_bp_rp_excess_factor                   0.039002705
# 81   phot_bp_n_contaminated_transits                          -0.0
# 82        phot_bp_n_blended_transits                          -0.0
# 83   phot_rp_n_contaminated_transits                          -0.0
# 84        phot_rp_n_blended_transits                          -0.0
# 85                    phot_proc_mode                          -0.0
# 86                             bp_rp                    -7.3475304
# 87                              bp_g                     -8.431045
# 88                              g_rp                    -4.8746176
# 89                   radial_velocity                     -906.6071
# 90             radial_velocity_error                    0.11300004
# 91                    rv_method_used                           1.0
# 92                    rv_nb_transits                           2.0
# 93          rv_nb_deblended_transits                          -0.0
# 94        rv_visibility_periods_used                           1.0
# 95          rv_expected_sig_to_noise                     2.0000005
# 96               rv_renormalised_gof                     -9.411507
# 97                   rv_chisq_pvalue                          -0.0
# 98                  rv_time_duration                   0.074003704
# 99               rv_amplitude_robust                  0.0020561218
# 100                 rv_template_teff                        3100.0
# 101                 rv_template_logg                          -0.5
# 102                 rv_template_fe_h                          -5.0
# 103              rv_atm_param_origin                          -0.0
# 104                           vbroad                      5.000002
# 105                     vbroad_error                   0.064192854
# 106               vbroad_nb_transits                           6.0
# 107                         grvs_mag                     2.7579873
# 108                   grvs_mag_error                   0.004000003
# 109             grvs_mag_nb_transits                           2.0
# 110            rvs_spec_sig_to_noise                     15.000006
# 111               phot_variable_flag                 NOT_AVAILABLE
# 112                                l        1.0606335061246417e-07
# 113                                b            -89.99366530605397
# 114                          ecl_lon          5.21887866629631e-07
# 115                          ecl_lat            -89.99954651413846
# 116                in_qso_candidates                         False
# 117             in_galaxy_candidates                         False
# 118                  non_single_star                             0
# 119                has_xp_continuous                         False
# 120                   has_xp_sampled                         False
# 121                          has_rvs                         False
# 122             has_epoch_photometry                         False
# 123                     has_epoch_rv                         False
# 124                 has_mcmc_gspphot                         False
# 125                     has_mcmc_msc                         False
# 126              in_andromeda_survey                         False
# 127     classprob_dsc_combmod_quasar                          -0.0
# 128     classprob_dsc_combmod_galaxy                          -0.0
# 129       classprob_dsc_combmod_star                          -0.0
# 130                     teff_gspphot                     2501.1814
# 131               teff_gspphot_lower                     2500.3027
# 132               teff_gspphot_upper                     2503.5662
# 133                     logg_gspphot                          -0.5
# 134               logg_gspphot_lower                          -0.5
# 135               logg_gspphot_upper                       -0.4999
# 136                       mh_gspphot                       -4.1503
# 137                 mh_gspphot_lower                       -4.1505
# 138                 mh_gspphot_upper                       -4.1498
# 139                 distance_gspphot                        1.3011
# 140           distance_gspphot_lower                        1.3006
# 141           distance_gspphot_upper                        1.3013
# 142                    azero_gspphot                          -0.0
# 143              azero_gspphot_lower                          -0.0
# 144              azero_gspphot_upper                        0.0001
# 145                       ag_gspphot                          -0.0
# 146                 ag_gspphot_lower                          -0.0
# 147                 ag_gspphot_upper                        0.0001
# 148                 ebpminrp_gspphot                          -0.0
# 149           ebpminrp_gspphot_lower                          -0.0
# 150           ebpminrp_gspphot_upper                        0.0001
# 151                  libname_gspphot                             A
#
#                        max_value  null_count
# 0            1636148068921376768           0
# 1    Gaia DR3 999999988604363776           0
# 2            6917528997577384320           0
# 3                     1811709770           0
# 4                         2016.0           0
# 5               359.999999939548           0
# 6                      99.997635           0
# 7              89.99005196682685           0
# 8                       99.97974           0
# 9              768.0665391873573   343964953
# 10                      5.802274   343964953
# 11                     15400.477   343964953
# 12                     10393.349   343964953
# 13             6765.995136250774   343964953
# 14                      3.447368   343964953
# 15            10362.394206546573   343964953
# 16                     3.4449604   343964953
# 17                     0.9999991           0
# 18                     0.9898032   343964953
# 19                     0.9931951   343964953
# 20                     0.9954832   343964953
# 21                     0.9782114   343964953
# 22                    0.98989755   343964953
# 23                     0.9971811   343964953
# 24                     0.9391216   343964953
# 25                     0.9781327   343964953
# 26                    0.99714994   343964953
# 27                          1564           0
# 28                          1524           0
# 29                          1556           0
# 30                           299           0
# 31                     10382.003           0
# 32                  5779107300.0           0
# 33                     1131.5846           0
# 34                   194326672.0           0
# 35                            95           0
# 36                          True           0
# 37                     4.5718956  1226293062
# 38                      5.841313   929381662
# 39                     1.0967505   929381662
# 40                    0.91704756   929381662
# 41                    0.91690594   929381662
# 42                     0.8844462   929381662
# 43                     0.8416601   929381662
# 44                    0.88046676   929381662
# 45                           178           0
# 46                            33           0
# 47                 26307864600.0           0
# 48                           328           0
# 49                           328           0
# 50                           242           0
# 51                     14408.159           0
# 52                         180.0           0
# 53                           100           0
# 54                           100           0
# 55                    116.016365   343964953
# 56                     0.9999982    32419826
# 57                    0.99999297    32419826
# 58                     0.9999945    32419826
# 59                      0.999999    32419826
# 60                         180.0    32419826
# 61                          90.0    32419826
# 62                          60.0    32419826
# 63                          45.0    32419826
# 64                          True           0
# 65                          2395           0
# 66             3822116782.633696     5455339
# 67                    61207728.0     5455339
# 68                     22926.803     5455339
# 69                     22.956425     5455339
# 70                           268           0
# 71            1500432409.3837109   269676299
# 72                    71123240.0   269676299
# 73                    94195456.0   269676302
# 74                     25.333084   269676299
# 75                           263           0
# 76            1591127209.4126902   256711832
# 77                    89607720.0   256711832
# 78                    81374416.0   256711835
# 79                     24.695997   256711832
# 80                     17088.953   270939431
# 81                         211.0   269676299
# 82                         263.0   269676299
# 83                         216.0   256711832
# 84                         262.0   256711832
# 85                           2.0     1602051
# 86                     10.193149   270939282
# 87                      7.015131   269681608
# 88                     11.520412   260559960
# 89                      914.7007  1777897588
# 90                      39.99959  1777897588
# 91                           2.0  1777897588
# 92                         227.0  1777897588
# 93                         152.0  1777897588
# 94                          33.0  1777897588
# 95                     2867.8718  1777897588
# 96                      809.9844  1804716766
# 97                           1.0  1804728523
# 98                     1037.7318  1777897588
# 99                     1293.1023  1804728523
# 100                      14500.0  1777897588
# 101                          5.0  1777897588
# 102                          1.0  1777897588
# 103                        555.0  1777897588
# 104                     497.6113  1808185094
# 105                    303.69775  1808185094
# 106                         91.0  1808185094
# 107                    14.099998  1779477584
# 108                     2.007191  1779477584
# 109                        219.0  1779477584
# 110                    2008.3867  1810710126
# 111                     VARIABLE           0
# 112            359.9999999850258           0
# 113            89.98796453163729           0
# 114            359.9999981083096           0
# 115            89.99008000608518           0
# 116                         True           0
# 117                         True           0
# 118                            7           0
# 119                         True           0
# 120                         True           0
# 121                         True           0
# 122                         True           0
# 123                         True           0
# 124                         True           0
# 125                         True           0
# 126                         True           0
# 127                          1.0   220949302
# 128                          1.0   220949302
# 129                          1.0   220949302
# 130                     41504.02  1340950508
# 131                    41460.203  1340950508
# 132                    41532.008  1340950508
# 133                       5.4957  1340950508
# 134                        5.487  1340950508
# 135                       5.4992  1340950508
# 136                          0.8  1340950508
# 137                       0.7999  1340950508
# 138                       0.8001  1340950508
# 139                     36165.09  1340950508
# 140                    35664.418  1340950508
# 141                    36337.793  1340950508
# 142                         10.0  1340950508
# 143                       9.9999  1340950508
# 144                         10.0  1340950508
# 145                       7.4106  1340950508
# 146                         7.41  1340950508
# 147                       7.4111  1340950508
# 148                       4.2257  1340950508
# 149                       4.2245  1340950508
# 150                       4.2262  1340950508
# 151                      PHOENIX  1340950508

# %%
# %%time

aggregate_column_statistics('https://data.lsdb.io/unstable/ztf/zubercal/_metadata')
# Out:
# CPU times: user 5.79 s, sys: 318 ms, total: 6.11 s
# Wall time: 27.5 s
#    column_names            min_value           max_value null_count
# 0           mjd    58197.13738121402   59942.22293158946          0
# 1           mag   -87.34929656982422   56.31169891357422          0
# 2        objdec  -31.591880798339844   87.52532196044922          0
# 3         objra                 -0.0               360.0          0
# 4        magerr                    0               65535          0
# 5      objectid    70080135368679987  213033390123621252          0
# 6          info                   -1            67113780          0
# 7          flag                    0                  52          0
# 8        rcidin                    0                  63          0
# 9       fieldid                  199                1893          0
# 10         band                    g                   r          0
