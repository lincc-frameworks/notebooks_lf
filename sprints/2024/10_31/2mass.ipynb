# %% [markdown]
# # 2MASS
#
# This notebook demonstrates the importing process for 2MASS.

# %%
import glob
import lsdb
import numpy as np
import numpy.testing as npt
import pandas as pd
from dask.distributed import Client
from hats_import.pipeline import pipeline_with_client
from hats_import.catalog.arguments import ImportArguments
from hats_import.catalog.file_readers import CsvReader

# %% [markdown]
# Load all raw point source file paths:

# %%
in_file_paths = glob.glob("/epyc/data3/hipscat/raw/two_mass/psc_**.gz")
in_file_paths.sort()
print(f"{len(in_file_paths)} files")
# Out:
# 92 files

# %% [markdown]
# Load the column names and types from a side file (inferred from the official [schema](https://irsa.ipac.caltech.edu/2MASS/download/allsky/twomass_psc_schema)):

# %%
type_frame = pd.read_csv("/epyc/data3/hipscat/raw/two_mass/schema.csv")
type_map = dict(zip(type_frame["name"], type_frame["type"]))
type_map
# Out:
# {'ra': 'float64',
#  'decl': 'float64',
#  'err_maj': 'Float32',
#  'err_min': 'Float32',
#  'err_ang': 'Int16',
#  'designation': 'str',
#  'j_m': 'Float32',
#  'j_cmsig': 'Float32',
#  'j_msigcom': 'Float32',
#  'j_snr': 'Float32',
#  'h_m': 'Float32',
#  'h_cmsig': 'Float32',
#  'h_msigcom': 'Float32',
#  'h_snr': 'Float32',
#  'k_m': 'Float32',
#  'k_cmsig': 'Float32',
#  'k_msigcom': 'Float32',
#  'k_snr': 'Float32',
#  'ph_qual': 'str',
#  'rd_flg': 'str',
#  'bl_flg': 'str',
#  'cc_flg': 'str',
#  'ndet': 'str',
#  'prox': 'Float32',
#  'pxpa': 'Int16',
#  'pxcntr': 'Int64',
#  'gal_contam': 'Int16',
#  'mp_flg': 'Int16',
#  'pts_key': 'Int64',
#  'hemis': 'str',
#  'date': 'str',
#  'scan': 'Int16',
#  'glon': 'Float32',
#  'glat': 'Float32',
#  'x_scan': 'Float32',
#  'jdate': 'Float64',
#  'j_psfchi': 'Float32',
#  'h_psfchi': 'Float32',
#  'k_psfchi': 'Float32',
#  'j_m_stdap': 'Float32',
#  'j_msig_stdap': 'Float32',
#  'h_m_stdap': 'Float32',
#  'h_msig_stdap': 'Float32',
#  'k_m_stdap': 'Float64',
#  'k_msig_stdap': 'Float64',
#  'dist_edge_ns': 'Int64',
#  'dist_edge_ew': 'Int64',
#  'dist_edge_flg': 'str',
#  'dup_src': 'Int16',
#  'use_src': 'Int16',
#  'a': 'str',
#  'dist_opt': 'Float32',
#  'phi_opt': 'Int16',
#  'b_m_opt': 'Float32',
#  'vr_m_opt': 'Float32',
#  'nopt_mchs': 'Int16',
#  'ext_key': 'Int64',
#  'scan_key': 'Int64',
#  'coadd_key': 'Int64',
#  'coadd': 'Int16'}

# %%
args = ImportArguments(
    output_artifact_name="two_mass",
    input_file_list=in_file_paths,
    file_reader=CsvReader(
        header=None,
        delimiter="|", 
        column_names=type_frame["name"].values.tolist(),
        type_map=type_map,
        compression="gzip",
        na_values="\\N"
    ),
    output_path="/epyc/data3/hats/catalogs",
    dask_tmp="/epyc/data3/hats/tmp",
    ra_column="ra",
    dec_column="decl",
    resume=False,
)

# %%
with Client(n_workers=32, memory_limit="8GiB") as client:
    pipeline_with_client(args,client)
# Out:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39929 instead
#   warnings.warn(
# Planning  : 100%|██████████| 4/4 [00:00<00:00, 57.25it/s]
# Mapping   :   0%|          | 0/92 [00:00<?, ?it/s]/astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# Mapping   : 100%|██████████| 92/92 [01:33<00:00,  1.02s/it]
# Binning   : 100%|██████████| 2/2 [01:26<00:00, 43.16s/it]
# Splitting :   0%|          | 0/92 [00:00<?, ?it/s]/astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/hats/io/file_io/file_io.py:122: RuntimeWarning: compression has no effect when passing a non-binary object as input.
#   with pd.read_csv(csv_file, chunksize=chunksize, **kwargs) as reader:
# Splitting : 100%|██████████| 92/92 [14:05<00:00,  9.19s/it]
# Reducing  : 100%|██████████| 1107/1107 [04:54<00:00,  3.76it/s]
# Finishing : 100%|██████████| 4/4 [00:03<00:00,  1.02it/s]

# %% [markdown]
# Let's see what the schema looks like:

# %%
from pyarrow.parquet import read_metadata
meta = read_metadata("/epyc/data3/hats/catalogs/two_mass/dataset/_metadata")
meta.schema
# Out:
# <pyarrow._parquet.ParquetSchema object at 0x7f1f1411f400>
# required group field_id=-1 schema {
#   optional double field_id=-1 ra;
#   optional double field_id=-1 decl;
#   optional float field_id=-1 err_maj;
#   optional float field_id=-1 err_min;
#   optional int32 field_id=-1 err_ang (Int(bitWidth=16, isSigned=true));
#   optional binary field_id=-1 designation (String);
#   optional float field_id=-1 j_m;
#   optional float field_id=-1 j_cmsig;
#   optional float field_id=-1 j_msigcom;
#   optional float field_id=-1 j_snr;
#   optional float field_id=-1 h_m;
#   optional float field_id=-1 h_cmsig;
#   optional float field_id=-1 h_msigcom;
#   optional float field_id=-1 h_snr;
#   optional float field_id=-1 k_m;
#   optional float field_id=-1 k_cmsig;
#   optional float field_id=-1 k_msigcom;
#   optional float field_id=-1 k_snr;
#   optional binary field_id=-1 ph_qual (String);
#   optional binary field_id=-1 rd_flg (String);
#   optional binary field_id=-1 bl_flg (String);
#   optional binary field_id=-1 cc_flg (String);
#   optional binary field_id=-1 ndet (String);
#   optional float field_id=-1 prox;
#   optional int32 field_id=-1 pxpa (Int(bitWidth=16, isSigned=true));
#   optional int64 field_id=-1 pxcntr;
#   optional int32 field_id=-1 gal_contam (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 mp_flg (Int(bitWidth=16, isSigned=true));
#   optional int64 field_id=-1 pts_key;
#   optional binary field_id=-1 hemis (String);
#   optional binary field_id=-1 date (String);
#   optional int32 field_id=-1 scan (Int(bitWidth=16, isSigned=true));
#   optional float field_id=-1 glon;
#   optional float field_id=-1 glat;
#   optional float field_id=-1 x_scan;
#   optional double field_id=-1 jdate;
#   optional float field_id=-1 j_psfchi;
#   optional float field_id=-1 h_psfchi;
#   optional float field_id=-1 k_psfchi;
#   optional float field_id=-1 j_m_stdap;
#   optional float field_id=-1 j_msig_stdap;
#   optional float field_id=-1 h_m_stdap;
#   optional float field_id=-1 h_msig_stdap;
#   optional double field_id=-1 k_m_stdap;
#   optional double field_id=-1 k_msig_stdap;
#   optional int64 field_id=-1 dist_edge_ns;
#   optional int64 field_id=-1 dist_edge_ew;
#   optional binary field_id=-1 dist_edge_flg (String);
#   optional int32 field_id=-1 dup_src (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 use_src (Int(bitWidth=16, isSigned=true));
#   optional binary field_id=-1 a (String);
#   optional float field_id=-1 dist_opt;
#   optional int32 field_id=-1 phi_opt (Int(bitWidth=16, isSigned=true));
#   optional float field_id=-1 b_m_opt;
#   optional float field_id=-1 vr_m_opt;
#   optional int32 field_id=-1 nopt_mchs (Int(bitWidth=16, isSigned=true));
#   optional int64 field_id=-1 ext_key;
#   optional int64 field_id=-1 scan_key;
#   optional int64 field_id=-1 coadd_key;
#   optional int32 field_id=-1 coadd (Int(bitWidth=16, isSigned=true));
#   optional int32 field_id=-1 Norder (Int(bitWidth=8, isSigned=false));
#   optional int64 field_id=-1 Dir (Int(bitWidth=64, isSigned=false));
#   optional int64 field_id=-1 Npix (Int(bitWidth=64, isSigned=false));
#   optional int64 field_id=-1 _healpix_29;
# }

# %% [markdown]
# ### Veritication checks
#
# IPAC provides a [query](https://irsa.ipac.caltech.edu/2MASS/download/allsky/verification_query_psc.html) for data verification. Let's use it on our newly imported catalog and make sure columns sum up to the expected amounts.

# %%
two_mass = lsdb.read_hats("/epyc/data3/hats/catalogs/two_mass")
two_mass
# Out:
# Dask NestedFrame Structure:
#                                   ra             decl         err_maj         err_min         err_ang      designation             j_m         j_cmsig       j_msigcom           j_snr             h_m         h_cmsig       h_msigcom           h_snr             k_m         k_cmsig       k_msigcom           k_snr          ph_qual           rd_flg           bl_flg           cc_flg             ndet            prox            pxpa          pxcntr      gal_contam          mp_flg         pts_key            hemis             date            scan            glon            glat          x_scan            jdate        j_psfchi        h_psfchi        k_psfchi       j_m_stdap    j_msig_stdap       h_m_stdap    h_msig_stdap        k_m_stdap     k_msig_stdap    dist_edge_ns    dist_edge_ew    dist_edge_flg         dup_src         use_src                a        dist_opt         phi_opt         b_m_opt        vr_m_opt       nopt_mchs         ext_key        scan_key       coadd_key           coadd          Norder              Dir             Npix
# npartitions=1107
# 0                    double[pyarrow]  double[pyarrow]  float[pyarrow]  float[pyarrow]  int16[pyarrow]  string[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  string[pyarrow]  string[pyarrow]  string[pyarrow]  string[pyarrow]  string[pyarrow]  float[pyarrow]  int16[pyarrow]  int64[pyarrow]  int16[pyarrow]  int16[pyarrow]  int64[pyarrow]  string[pyarrow]  string[pyarrow]  int16[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  double[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  double[pyarrow]  double[pyarrow]  int64[pyarrow]  int64[pyarrow]  string[pyarrow]  int16[pyarrow]  int16[pyarrow]  string[pyarrow]  float[pyarrow]  int16[pyarrow]  float[pyarrow]  float[pyarrow]  int16[pyarrow]  int64[pyarrow]  int64[pyarrow]  int64[pyarrow]  int16[pyarrow]  uint8[pyarrow]  uint64[pyarrow]  uint64[pyarrow]
# 18014398509481984                ...              ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...              ...              ...              ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...              ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# ...                              ...              ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...              ...              ...              ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...              ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# 3454260914193170432              ...              ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...              ...              ...              ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...              ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# 3458764513820540928              ...              ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...              ...              ...              ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...              ...              ...             ...             ...              ...             ...             ...              ...             ...             ...             ...             ...             ...             ...             ...             ...             ...             ...              ...              ...
# Dask Name: nestedframe, 3 expressions
# Expr=MapPartitions(NestedFrame)

# %%
two_mass.head(10)
# Out:
#                      ra      decl  err_maj  err_min  err_ang  \
# _healpix_29
# 2943408919    44.996055  0.005565     0.17     0.16       76
# 29153088558   45.004857  0.019806     0.06     0.06       90
# 29639235405   45.004193  0.020956     0.06     0.06       90
# 162212337124  44.995074  0.038204     0.38     0.31        0
# 187874191277  44.963851  0.043587     0.22     0.17       95
# 282956647929  45.048281  0.048329     0.18     0.07        0
# 425727676968  45.023564  0.068472     0.18     0.07        0
# 643736796518  44.993307  0.076423     0.07     0.06        4
# 681422857682  44.969132  0.084458     0.13     0.12       88
# 687145892547  44.978474  0.092522     0.25      0.2      179
#
#                     designation        j_m  j_cmsig  j_msigcom       j_snr  \
# _healpix_29
# 2943408919    02595905+0000200   16.375999    0.097      0.097        11.3
# 29153088558   03000116+0001113      12.529    0.021      0.024  389.799988
# 29639235405   03000100+0001154      14.845    0.055      0.056   46.200001
# 162212337124  02595881+0002175      16.746    0.133      0.134         8.0
# 187874191277  02595132+0002369      16.476    0.112      0.113        10.3
# 282956647929  03001158+0002539      13.354    0.022      0.025  153.399994
# 425727676968  03000565+0004064      14.729    0.036      0.038   43.200001
# 643736796518  02595839+0004351      14.921    0.034      0.036   43.099998
# 681422857682  02595259+0005040      16.086    0.085      0.086        14.7
# 687145892547  02595483+0005330   16.504999    0.122      0.122        10.0
#
#               ...    b_m_opt   vr_m_opt  nopt_mchs  ext_key  scan_key  \
# _healpix_29   ...
# 2943408919    ...       17.9       16.9          1     <NA>     69347
# 29153088558   ...       15.0       13.8          1     <NA>     69347
# 29639235405   ...       <NA>       <NA>          0     <NA>     69347
# 162212337124  ...       <NA>       <NA>          0     <NA>     69347
# 187874191277  ...  18.700001  17.700001          1     <NA>     69347
# 282956647929  ...       15.5       14.9          1     <NA>     61142
# 425727676968  ...       17.4       16.1          1     <NA>     61142
# 643736796518  ...       16.5       16.1          1     <NA>     69347
# 681422857682  ...  18.299999       17.5          1     <NA>     69347
# 687145892547  ...       18.9  18.299999          1     <NA>     69347
#
#               coadd_key  coadd  Norder Dir Npix
# _healpix_29
# 2943408919      1594959      9       2   0    0
# 29153088558     1594959      9       2   0    0
# 29639235405     1594959      9       2   0    0
# 162212337124    1594959      9       2   0    0
# 187874191277    1594959      9       2   0    0
# 282956647929    1406266    267       2   0    0
# 425727676968    1406266    267       2   0    0
# 643736796518    1594959      9       2   0    0
# 681422857682    1594959      9       2   0    0
# 687145892547    1594959      9       2   0    0
#
# [10 rows x 63 columns]

# %%
desired = [
    306810325437475788, 
    306815556538478936, 
    16902776758555, 
    32666066948, 
    2048692118201,
    388758631396659, 
    64617139213, 
    16048, 
    729878, 
    464456155, 
    79798372, 
    369187043, 
    64916239773,
    69388217174, 
    2670725813652, 
    29279563815
]

# %%
def compute_sums(df):
    sums = [
        df["pts_key"].sum(),
        df["pxcntr"].sum(),
        df["scan_key"].sum(),
        df["scan"].sum(),
        df["ext_key"].sum(),
        df["coadd_key"].sum(),
        df["coadd"].sum(),
        df["mp_flg"].sum(),
        df["gal_contam"].sum(),
        df["use_src"].sum(),
        df["dup_src"].sum(),
        df["nopt_mchs"].sum(),
        df["phi_opt"].sum(),
        df["dist_edge_ew"].sum(),
        df["dist_edge_ns"].sum(),
        df["err_ang"].sum(),
    ]
    return pd.DataFrame(sums)

results = two_mass.map_partitions(lambda df: compute_sums(df))

with Client(n_workers=64, memory_limit="4GiB") as client:
    sums = results.compute()
# Out:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 39526 instead
#   warnings.warn(

# %%
splits = np.array_split(sums, len(two_mass.get_healpix_pixels()))
total_sums = np.sum(splits, axis=0).flatten()
total_sums
# Out:
# /astro/users/smcampos/.conda/envs/hats-import/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'NestedFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'NestedFrame.transpose' instead.
#   return bound(*args, **kwds)
# array([306810325437475788, 306815556538478936,     16902776758555,
#               32666066948,      2048692118201,    388758631396659,
#               64617139213,              16048,             729878,
#                 464456155,           79798372,          369187043,
#               64916239773,        69388217174,      2670725813652,
#               29279563815])

# %%
npt.assert_array_equal(total_sums, desired)
