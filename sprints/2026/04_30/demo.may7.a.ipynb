# %% [markdown]
# ## Aggregate column statistics - before
#
# Simply uses the version of `hats` before any of this `per_partition_statistics` nonsense even started.

# %%
import hats

# %%
hats.__version__
# Out:
# '0.9.1.dev1+g13819050a.d20260326'

# %%
# %%time
gaia_http = hats.read_hats("https://data.lsdb.io/hats/gaia_dr3/gaia/")
# Out:
# CPU times: user 101 ms, sys: 70.6 ms, total: 172 ms
# Wall time: 2.88 s

# %%
# %%time
gaia_http.aggregate_column_statistics()
# Out:
# CPU times: user 10.5 s, sys: 1.08 s, total: 11.6 s
# Wall time: 22.4 s
#                                            min_value  \
# column_names
# solution_id                      1636148068921376768
# designation             Gaia DR3 1000000057322000000
# ...                                              ...
# ebpminrp_gspphot_upper         9.999999747378752e-05
# libname_gspphot                                    A
#
#                                           max_value  null_count   row_count
# column_names
# solution_id                     1636148068921376768           0  1812731847
# designation             Gaia DR3 999999988604363776           0  1812731847
# ...                                             ...         ...         ...
# ebpminrp_gspphot_upper            4.226200103759766  1341620712  1812731847
# libname_gspphot                             PHOENIX  1341620712  1812731847
#
# [152 rows x 4 columns]

# %%
# %%time
gaia_http.per_pixel_statistics()
# Out:
# CPU times: user 12.1 s, sys: 686 ms, total: 12.8 s
# Wall time: 22.1 s
#                      solution_id: min_value solution_id: max_value  \
# Order: 2, Pixel: 0      1636148068921376768    1636148068921376768
# Order: 2, Pixel: 1      1636148068921376768    1636148068921376768
# ...                                     ...                    ...
# Order: 3, Pixel: 766    1636148068921376768    1636148068921376768
# Order: 3, Pixel: 767    1636148068921376768    1636148068921376768
#
#                       solution_id: null_count  solution_id: row_count  \
# Order: 2, Pixel: 0                          0                  726621
# Order: 2, Pixel: 1                          0                 1485249
# ...                                       ...                     ...
# Order: 3, Pixel: 766                        0                 1110599
# Order: 3, Pixel: 767                        0                  820930
#
# ...
