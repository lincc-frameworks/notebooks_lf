# %%
import lsdb

# %%
gaia = lsdb.open_catalog('s3://stpubdata/gaia/gaia_dr3/public/hats')
gaia
# Out:
# Dask NestedFrame Structure:
# ...

# %%
gaia.cone_search(ra=283.44639, dec=33.06623, radius_arcsec=10000)
# Out:
# Dask NestedFrame Structure:
# ...

# %%
gaia.cone_search(ra=283.44639, dec=33.06623, radius_arcsec=10000)[["ra", "dec"]]
# Out:
# Dask NestedFrame Structure:
#                                   ra              dec
# npartitions=3
# 1020065315599417344  double[pyarrow]  double[pyarrow]
# 1021191215506259968              ...              ...
# 1044835113549955072              ...              ...
# 1049338713177325568              ...              ...
# Dask Name: getitem, 6 expressions
# Expr=MapPartitions(search_points)[['ra', 'dec']]

# %%
from distributed import Client
try:
    client.shutdown()
    client.close()
except:
    pass
client = Client(n_workers=4)
# Out:
# /Users/smcmu/.pyenv/versions/lsdb/lib/python3.12/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 63578 instead
#   warnings.warn(

# %%
df = gaia[["ra", "dec"]].cone_search(ra=283.44639, dec=33.06623, radius_arcsec=10000).compute()
mem_use = df.memory_usage()

# %%
sum(mem_use)/1000000
# Out:
# 28.327104
