# %%
import lsdb

# %%
gaia = lsdb.open_catalog('s3://stpubdata/gaia/gaia_dr3/public/hats')
gaia
# Out:
# Dask NestedFrame Structure:
# ...

# %%
gaia[["solution_id"]]
# Out:
# Dask NestedFrame Structure:
#                         solution_id
# npartitions=2016
# 0                    int64[pyarrow]
# 18014398509481984               ...
# ...                             ...
# 3454260914193170432             ...
# 3458764513820540928             ...
# Dask Name: getitem, 4 expressions
# Expr=MapPartitions(NestedFrame)[['solution_id']]

# %%
gaia[["solution_id"]].partitions[0]
# Out:
# Dask NestedFrame Structure:
#                       solution_id
# npartitions=1
# 0                  int64[pyarrow]
# 18014398509481984             ...
# Dask Name: partitions, 5 expressions
# Expr=Partitions(frame=MapPartitions(NestedFrame)[['solution_id']], partitions=[0])

# %%
gaia[["solution_id"]].compute()
# Out:
# WARNING:root:The estimated size of the catalog is 29.0 GB. Computing the catalog will load all data into memory and may cause your system to run out of memory.Consider using `write_catalog` to write the catalog to disk, or selecting a subset of the catalog to compute.
# Computing Catalog:   0%|          | 0/8065 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 gaia[["solution_id"]].compute()
#
# File ~/code/lsdb/src/lsdb/catalog/dataset/healpix_dataset.py:253, in HealpixDataset.compute(self, progress_bar, tqdm_kwargs)
#     251 desc = tqdm_kwargs.pop("desc", "Computing Catalog") if tqdm_kwargs else "Computing Catalog"
#     252 with TqdmCallback(desc=desc, disable=not progress_bar, **(tqdm_kwargs or {})):
# --> 253     res = self._ddf.compute()
#     254 return res
#
# ...

# %%
gaia[["solution_id"]].partitions[0].compute().memory_usage()
# Out:
# Computing Catalog:   0%|          | 0/4 [00:00<?, ?it/s]
# Index          5903796
# solution_id    5903796
# dtype: int64

# %%
f"{(5903796 + 5903796)/1000000} MB"
# Out:
# '11.807592 MB'
