# %% [markdown]
# # SDSS DR7 Spectra catalog with LSDB

# %%
# %pip install git+https://github.com/astronomy-commons/hats
# %pip install git+https://github.com/astronomy-commons/lsdb
# Out:
# Collecting git+https://github.com/astronomy-commons/hats
#   Cloning https://github.com/astronomy-commons/hats to /private/var/folders/w1/lh3h4s7d5g10rdlfj4h0mshw0000gn/T/pip-req-build-_wgsgsui
#   Running command git clone --filter=blob:none --quiet https://github.com/astronomy-commons/hats /private/var/folders/w1/lh3h4s7d5g10rdlfj4h0mshw0000gn/T/pip-req-build-_wgsgsui
#   Resolved https://github.com/astronomy-commons/hats to commit 499c66aa5db1d9f1b8bd10e3a2741b1f0e673e10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (3.9.5)
# Requirement already satisfied: astropy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (6.0.1)
# Requirement already satisfied: fsspec>=2023.10.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (2024.6.1)
# Requirement already satisfied: healpy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (1.17.3)
# Requirement already satisfied: jproperties in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (2.1.2)
# Requirement already satisfied: matplotlib<3.9,>=3.3 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (3.8.4)
# Requirement already satisfied: mocpy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (0.16.1)
# Requirement already satisfied: numba>=0.58 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (0.60.0)
# Requirement already satisfied: numpy<3 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (1.26.4)
# Requirement already satisfied: pandas in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (2.2.3)
# Requirement already satisfied: pyarrow>=14.0.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (16.1.0)
# Requirement already satisfied: pydantic in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (2.9.2)
# Requirement already satisfied: scipy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (4.12.2)
# Requirement already satisfied: universal-pathlib in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats==0.4.2.dev5+g499c66a) (0.2.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats==0.4.2.dev5+g499c66a) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from numba>=0.58->hats==0.4.2.dev5+g499c66a) (0.43.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats==0.4.2.dev5+g499c66a) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats==0.4.2.dev5+g499c66a) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats==0.4.2.dev5+g499c66a) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats==0.4.2.dev5+g499c66a) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats==0.4.2.dev5+g499c66a) (1.9.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from astropy->hats==0.4.2.dev5+g499c66a) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.2.26.0.28.55 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from astropy->hats==0.4.2.dev5+g499c66a) (0.2024.7.22.0.34.13)
# Requirement already satisfied: PyYAML>=3.13 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from astropy->hats==0.4.2.dev5+g499c66a) (6.0.1)
# Requirement already satisfied: six~=1.13 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from jproperties->hats==0.4.2.dev5+g499c66a) (1.16.0)
# Requirement already satisfied: cdshealpix>=0.6.4 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from mocpy->hats==0.4.2.dev5+g499c66a) (0.6.5)
# Requirement already satisfied: networkx>=2.5 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from mocpy->hats==0.4.2.dev5+g499c66a) (3.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pandas->hats==0.4.2.dev5+g499c66a) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pandas->hats==0.4.2.dev5+g499c66a) (2024.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pydantic->hats==0.4.2.dev5+g499c66a) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pydantic->hats==0.4.2.dev5+g499c66a) (2.23.4)
# Requirement already satisfied: idna>=2.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp->hats==0.4.2.dev5+g499c66a) (3.7)
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/astronomy-commons/lsdb
#   Cloning https://github.com/astronomy-commons/lsdb to /private/var/folders/w1/lh3h4s7d5g10rdlfj4h0mshw0000gn/T/pip-req-build-s8gcoscw
#   Running command git clone --filter=blob:none --quiet https://github.com/astronomy-commons/lsdb /private/var/folders/w1/lh3h4s7d5g10rdlfj4h0mshw0000gn/T/pip-req-build-s8gcoscw
#   Resolved https://github.com/astronomy-commons/lsdb to commit 5ad61e1ed87b76a412e5064f11270b6c6df9dd40
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dask[complete] in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (2024.7.1)
# Requirement already satisfied: deprecated in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (1.2.14)
# Requirement already satisfied: hats>=0.4 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (0.4.2.dev5+g499c66a)
# Requirement already satisfied: lsst-sphgeom in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (27.2024.2600)
# Requirement already satisfied: nested-dask in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (0.2.1)
# Requirement already satisfied: nested-pandas in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (0.2.2)
# Requirement already satisfied: pyarrow in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (16.1.0)
# Requirement already satisfied: scipy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsdb==0.4.1.dev6+g5ad61e1) (1.14.0)
# Requirement already satisfied: aiohttp in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (3.9.5)
# Requirement already satisfied: astropy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (6.0.1)
# Requirement already satisfied: fsspec>=2023.10.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2024.6.1)
# Requirement already satisfied: healpy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.17.3)
# Requirement already satisfied: jproperties in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2.1.2)
# Requirement already satisfied: matplotlib<3.9,>=3.3 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (3.8.4)
# Requirement already satisfied: mocpy in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.16.1)
# Requirement already satisfied: numba>=0.58 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.60.0)
# Requirement already satisfied: numpy<3 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.26.4)
# Requirement already satisfied: pandas in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2.2.3)
# Requirement already satisfied: pydantic in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (4.12.2)
# Requirement already satisfied: universal-pathlib in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.2.5)
# Requirement already satisfied: click>=8.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (3.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (24.1)
# Requirement already satisfied: partd>=1.4.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (0.12.1)
# Requirement already satisfied: pyarrow-hotfix in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (0.6)
# Requirement already satisfied: lz4>=4.3.2 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (4.3.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from deprecated->lsdb==0.4.1.dev6+g5ad61e1) (1.16.0)
# Requirement already satisfied: hpgeom>=0.8.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from lsst-sphgeom->lsdb==0.4.1.dev6+g5ad61e1) (1.3.2)
# Requirement already satisfied: dask-expr in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from nested-dask->lsdb==0.4.1.dev6+g5ad61e1) (1.1.9)
# Requirement already satisfied: distributed==2024.7.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (2024.7.1)
# Requirement already satisfied: jinja2>=2.10.3 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (1.0.8)
# Requirement already satisfied: psutil>=5.7.2 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (6.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (6.4.1)
# Requirement already satisfied: urllib3>=1.24.3 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (2.2.2)
# Requirement already satisfied: zict>=3.0.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (3.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from matplotlib<3.9,>=3.3->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from numba>=0.58->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pandas->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pandas->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from aiohttp->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.9.4)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from astropy->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.2.26.0.28.55 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from astropy->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.2024.7.22.0.34.13)
# Requirement already satisfied: bokeh>=2.4.2 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (3.5.0)
# Requirement already satisfied: six~=1.13 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from jproperties->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (1.16.0)
# Requirement already satisfied: cdshealpix>=0.6.4 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from mocpy->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.6.5)
# Requirement already satisfied: networkx>=2.5 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from mocpy->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (3.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pydantic->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from pydantic->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (2.23.4)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from bokeh>=2.4.2->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from jinja2>=2.10.3->distributed==2024.7.1->dask[complete]->lsdb==0.4.1.dev6+g5ad61e1) (2.1.5)
# Requirement already satisfied: idna>=2.0 in /Users/hombit/.virtualenvs/lsdb/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp->hats>=0.4->lsdb==0.4.1.dev6+g5ad61e1) (3.7)
# Building wheels for collected packages: lsdb
#   Building wheel for lsdb (pyproject.toml) ... done
#   Created wheel for lsdb: filename=lsdb-0.4.1.dev6+g5ad61e1-py3-none-any.whl size=73681 sha256=72ad1523638e8f73316273358edfd5d2f27d2466c48ff5c766cfd5da28955532
#   Stored in directory: /private/var/folders/w1/lh3h4s7d5g10rdlfj4h0mshw0000gn/T/pip-ephem-wheel-cache-a_al96cj/wheels/1e/29/ed/8e64ab53c6090b0ce0ef8568f8a28517f52d566541d561806f
# Successfully built lsdb
# Installing collected packages: lsdb
#   Attempting uninstall: lsdb
#     Found existing installation: lsdb 0.4.0
#     Not uninstalling lsdb at /Users/hombit/projects/lincc-frameworks/lsdb/src, outside environment /Users/hombit/.virtualenvs/lsdb
#     Can't uninstall 'lsdb'. No files were found to uninstall.
# Successfully installed lsdb-0.4.1.dev5+g2225b1e
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
from lsdb import read_hats

# %%
CATALOG = "https://data.lsdb.io/hats/sdss_dr7_spectra/"

raw_catalog = read_hats(CATALOG)

# Pack spectra
SED_COLUMNS = ["flux", "ivar"] 
catalog = raw_catalog.nest_lists(
    base_columns=[col for col in raw_catalog.columns if col not in SED_COLUMNS],
    name="sed",
)
catalog
# Out:
# Dask NestedFrame Structure:
#                                              OBJID         HOLETYPE               RA              DEC                            MAG           STARL            EXPL         DEVAUCL          OBJTYPE           XFOCAL           YFOCAL  SPECTROGRAPHID         FIBERID      THROUGHPUT      PRIMTARGET       SECTARGET        OFFSETID     SCI_EXPTIME                      CALIBFLUX                 CALIBFLUX_IVAR         SFD_EBV                        andmask                         ormask                        wavedisp                         skyflux __index_level_0__          Norder              Dir             Npix                                                                   sed
# npartitions=1304
# 0                    list<element: int32>[pyarrow]  binary[pyarrow]  double[pyarrow]  double[pyarrow]  list<element: float>[pyarrow]  float[pyarrow]  float[pyarrow]  float[pyarrow]  binary[pyarrow]  double[pyarrow]  double[pyarrow]  int32[pyarrow]  int32[pyarrow]  int32[pyarrow]  int32[pyarrow]  int32[pyarrow]  int32[pyarrow]  float[pyarrow]  list<element: float>[pyarrow]  list<element: float>[pyarrow]  float[pyarrow]  list<element: int32>[pyarrow]  list<element: int32>[pyarrow]  list<element: double>[pyarrow]  list<element: double>[pyarrow]    int64[pyarrow]  uint8[pyarrow]  uint64[pyarrow]  uint64[pyarrow]  nested<flux: [list<element: double>], ivar: [list<element: double>]>
# 1125899906842624                               ...              ...              ...              ...                            ...             ...             ...             ...              ...              ...              ...             ...             ...             ...             ...             ...             ...             ...                            ...                            ...             ...                            ...                            ...                             ...                             ...               ...             ...              ...              ...                                                                   ...
# ...                                            ...              ...              ...              ...                            ...             ...             ...             ...              ...              ...              ...             ...             ...             ...             ...             ...             ...             ...                            ...                            ...             ...                            ...                            ...                             ...                             ...               ...             ...              ...              ...                                                                   ...
# 3457638613913698304                            ...              ...              ...              ...                            ...             ...             ...             ...              ...              ...              ...             ...             ...             ...             ...             ...             ...             ...                            ...                            ...             ...                            ...                            ...                             ...                             ...               ...             ...              ...              ...                                                                   ...
# 3458764513820540928                            ...              ...              ...              ...                            ...             ...             ...             ...              ...              ...              ...             ...             ...             ...             ...             ...             ...             ...                            ...                            ...             ...                            ...                            ...                             ...                             ...               ...             ...              ...              ...                                                                   ...
# Dask Name: lambda, 4 expressions
# Expr=MapPartitions(lambda)

# %%
ndf = catalog.head(5)

# %%
# Plot few spectra

# Values from the FITS header
COEFF0 = 3.5797    # Central wavelength (log10) of the first pixel
COEFF1 = 0.0001    # Log10 dispersion per pixel
CRPIX1 = 1         # Starting pixel (1-indexed)

for i, sed in enumerate(ndf["sed"]):
    waves = 10**(COEFF0 + COEFF1 * (np.arange(sed.shape[0]) + 1 - CRPIX1))
    plt.errorbar(waves, sed["flux"], np.sqrt(1/sed["ivar"]), ls='', alpha=0.05, color=f'C{i}')
    plt.plot(waves, sed["flux"], lw=2.0, color=f'C{i}', alpha=0.5)
plt.xlabel(r"Wavelength, $\AA$")
plt.ylabel(r"Flux, $10^{-17}$ erg/cm${^2}$/s/$\AA$")
# Out:
# Text(0, 0.5, 'Flux, $10^{-17}$ erg/cm${^2}$/s/$\\AA$')
